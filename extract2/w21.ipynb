# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd 
import re

# %%
details=[]
url="https://myanimelist.net/anime/season/2021/winter"
r_actn = requests.get(url)
htmlContent_actn=r_actn.content
soup_actn=BeautifulSoup(htmlContent_actn,'html.parser')
anime_s22=soup_actn.find_all('a',attrs={'class':"link-title",'href': re.compile("^https://")})
    
for text in anime_s22:         
        name=text.get_text()
        url=text.get('href')
        details.append({'title':name,'link':url})

# %%
details

# %%
anime=[]

for i in range(len(details)):
    anime_url=details[i]['link']
    r1=requests.get(anime_url)
    htmlContent1=r1.content
    soup1=BeautifulSoup(htmlContent1,'html.parser')
    jap_name=soup1.find('h1',class_="title-name h1_bold_none").text
    
    
    eng_name=soup1.find('p',class_="title-english title-inherit")
    if eng_name is not None:
        other_name=eng_name.text
    else:
        other_name=""
        
    
    genre=soup1.find_all("span", { 'itemprop':"genre"  })
    g_list=[]        
    for text in genre:
                
        gg=text.get_text()
        g_list.append(gg)
    
    rate=soup1.find('div',class_="score-label")
    if rate is not None:
        ratings=rate.text
    else:
        ratings=""
    
        
    studio=soup1.find('span',class_="information studio author")
    if studio is not None:
        studio_name=soup1.find('span',class_="information studio author").text
    else:
        studio_name=""
      
    type_info=soup1.find('span',class_="information type")
    if type_info is not None:
        type=type_info.text
    else:
        type=""
        
    
    rank=soup1.find('span',class_="numbers ranked").text
    
    mem=soup1.find('span',class_="numbers members").text
    
    syn=soup1.find("p", { 'itemprop':"description"}).text
    img=soup1.find("img", { 'itemprop':"image"})
    if img is not None:
        img_url=img['data-src']
    else:
        img_url=""

   
    anime.append({'title':jap_name,'title2':other_name,'genre':g_list,'ratings':ratings,'studio':studio_name,'type':type,'rank':rank,'members':mem,'description':syn,'img_url':img_url,'link':anime_url})

# %%
df=pd.DataFrame(anime)
df
# Out:
#                                         title  \
# 0        Shingeki no Kyojin: The Final Season
# 1                                    Horimiya
# 2    Mushoku Tensei: Isekai Ittara Honki Dasu
# 3                       Dr. Stone: Stone Wars
# 4            Yakusoku no Neverland 2nd Season
# ..                                        ...
# 282                         e-ma Nodo Ame CMs
# 283                  Sazae-san: Valentine-hen
# 284                              Endless Vide
# 285                    Kimi no Suki ni Deaou.
# 286                       Luna-ui Mabeobdogam
#
#                                     title2  \
# 0        Attack on Titan: The Final Season
# 1
# 2    Mushoku Tensei: Jobless Reincarnation
# 3
# 4          The Promised Neverland Season 2
# ..                                     ...
# 282
# 283      Sazae-san Valentine's Day Special
# 284
# 285
# 286                     Luna's Magic Class
#
#                                                  genre ratings  \
# 0    [Action, Drama, Gore, Military, Survival, Shou...    8.81
# 1                           [Romance, School, Shounen]    8.20
# 2       [Drama, Fantasy, Ecchi, Isekai, Reincarnation]    8.38
# 3    [Adventure, Comedy, Sci-Fi, Survival, Time Tra...    8.18
# 4    [Sci-Fi, Suspense, Psychological, Survival, Sh...    5.33
# ..                                                 ...     ...
# 282                                            [Music]    5.44
# 283                            [Comedy, Slice of Life]     N/A
# 284                       [Idols (Male), Mecha, Music]     N/A
# 285                                          [Romance]     N/A
# 286                                             [Kids]     N/A
#
#                        studio     type           rank            members  \
# 0                       MAPPA       TV     Ranked #30  Members 1,710,174
# 1                 CloverWorks       TV    Ranked #343  Members 1,123,547
# 2                 Studio Bind       TV    Ranked #185  Members 1,036,491
# 3           TMS Entertainment       TV    Ranked #365    Members 881,008
# 4                 CloverWorks       TV  Ranked #11915    Members 839,695
# ..                        ...      ...            ...                ...
# 282                            Special  Ranked #11569        Members 492
# 283                            Special  Ranked #15633        Members 217
# 284                            Special  Ranked #19691        Members 192
# 285  Liberty Animation Studio  Special  Ranked #21352         Members 74
# 286                            Special  Ranked #13798         Members 65
#
#                                            description  \
# 0    Gabi Braun and Falco Grice have been training ...
# 1    On the surface, the thought of Kyouko Hori and...
# 2    Despite being bullied, scorned, and oppressed ...
# 3    Senkuu has made it his goal to bring back two ...
# 4    Emma, Ray, and the rest of the older children ...
# ..                                                 ...
# 282  Commercials for e-ma throat drops featuring va...
# 283  Sazae-san Valentine's Special which includes f...
# 284  A special video for one of Ensemble Star's uni...
# 285  Commercials directed by Toshitaka Shinoda for ...
# 286  No synopsis information has been added to this...
#
#                                                img_url  \
# 0    https://cdn.myanimelist.net/images/anime/1000/...
# 1    https://cdn.myanimelist.net/images/anime/1695/...
# 2    https://cdn.myanimelist.net/images/anime/1530/...
# 3    https://cdn.myanimelist.net/images/anime/1711/...
# 4    https://cdn.myanimelist.net/images/anime/1815/...
# ..                                                 ...
# 282  https://cdn.myanimelist.net/images/anime/1599/...
# 283  https://cdn.myanimelist.net/images/anime/1689/...
# 284  https://cdn.myanimelist.net/images/anime/1684/...
# 285  https://cdn.myanimelist.net/images/anime/1355/...
# 286  https://cdn.myanimelist.net/images/anime/1253/...
#
#                                                   link
# 0    https://myanimelist.net/anime/40028/Shingeki_n...
# 1         https://myanimelist.net/anime/42897/Horimiya
# 2    https://myanimelist.net/anime/39535/Mushoku_Te...
# 3    https://myanimelist.net/anime/40852/Dr_Stone__...
# 4    https://myanimelist.net/anime/39617/Yakusoku_n...
# ..                                                 ...
# 282  https://myanimelist.net/anime/48432/e-ma_Nodo_...
# 283  https://myanimelist.net/anime/47542/Sazae-san_...
# 284   https://myanimelist.net/anime/49122/Endless_Vide
# 285  https://myanimelist.net/anime/53014/Kimi_no_Su...
# 286  https://myanimelist.net/anime/51756/Luna-ui_Ma...
#
# [287 rows x 11 columns]

# %%
df.to_csv('D:\\Coding\\projects\\anime recommendation\\extract2\\data\\w21.csv',index=False)
