# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd 
import re

# %%
details=[]
url="https://myanimelist.net/anime/season/2020/spring"
r_actn = requests.get(url)
htmlContent_actn=r_actn.content
soup_actn=BeautifulSoup(htmlContent_actn,'html.parser')
anime_s22=soup_actn.find_all('a',attrs={'class':"link-title",'href': re.compile("^https://")})
    
for text in anime_s22:         
        name=text.get_text()
        url=text.get('href')
        details.append({'title':name,'link':url})

# %%
details

# %%
anime=[]

for i in range(len(details)):
    anime_url=details[i]['link']
    r1=requests.get(anime_url)
    htmlContent1=r1.content
    soup1=BeautifulSoup(htmlContent1,'html.parser')
    jap_name=soup1.find('h1',class_="title-name h1_bold_none").text
    
    
    eng_name=soup1.find('p',class_="title-english title-inherit")
    if eng_name is not None:
        other_name=eng_name.text
    else:
        other_name=""
        
    
    genre=soup1.find_all("span", { 'itemprop':"genre"  })
    g_list=[]        
    for text in genre:
                
        gg=text.get_text()
        g_list.append(gg)
    
    rate=soup1.find('div',class_="score-label")
    if rate is not None:
        ratings=rate.text
    else:
        ratings=""
    
        
    studio=soup1.find('span',class_="information studio author")
    if studio is not None:
        studio_name=soup1.find('span',class_="information studio author").text
    else:
        studio_name=""
      
    type_info=soup1.find('span',class_="information type")
    if type_info is not None:
        type=type_info.text
    else:
        type=""
        
    
    rank=soup1.find('span',class_="numbers ranked").text
    
    mem=soup1.find('span',class_="numbers members").text
    
    syn=soup1.find("p", { 'itemprop':"description"}).text
    img=soup1.find("img", { 'itemprop':"image"})
    if img is not None:
        img_url=img['data-src']
    else:
        img_url=""

   
    anime.append({'title':jap_name,'title2':other_name,'genre':g_list,'ratings':ratings,'studio':studio_name,'type':type,'rank':rank,'members':mem,'description':syn,'img_url':img_url,'link':anime_url})

# %%
df=pd.DataFrame(anime)
df
# Out:
#                                                  title  \
# 0    Kaguya-sama wa Kokurasetai? Tensai-tachi no Re...
# 1                                          Kami no Tou
# 2                      Shokugeki no Souma: Gou no Sara
# 3                             Fruits Basket 2nd Season
# 4                                             Gleipnir
# ..                                                 ...
# 211                   Choujigen Game Neptune: Hi☆Light
# 212                                     number24 Recap
# 213                                 Shadowverse Recaps
# 214                                  Yi Guan Xing Shen
# 215  Microphone Soul Spinners: Kotodama Shoujo - Fu...
#
#                                 title2  \
# 0    Kaguya-sama: Love is War Season 2
# 1                         Tower of God
# 2           Food Wars! The Fifth Plate
# 3
# 4
# ..                                 ...
# 211  Hyperdimension Neptunia: Hi☆Light
# 212
# 213
# 214
# 215
#
#                                                  genre ratings  \
# 0    [Comedy, Psychological, Romantic Subtext, Scho...    8.65
# 1         [Action, Adventure, Drama, Fantasy, Mystery]    7.56
# 2                    [Gourmet, Ecchi, School, Shounen]    7.32
# 3       [Drama, Romance, Supernatural, School, Shoujo]    8.56
# 4       [Action, Mystery, Supernatural, Ecchi, Seinen]    7.00
# ..                                                 ...     ...
# 211          [Action, Comedy, Fantasy, Sci-Fi, Parody]    6.72
# 212                                   [Sports, School]    6.09
# 213                           [Fantasy, Strategy Game]    5.51
# 214                                    [Slice of Life]    6.35
# 215                                            [Music]     N/A
#
#                      studio     type           rank            members  \
# 0              A-1 Pictures       TV     Ranked #68  Members 1,170,724
# 1    Telecom Animation Film       TV   Ranked #1510    Members 816,677
# 2                 J.C.Staff       TV   Ranked #2401    Members 469,805
# 3         TMS Entertainment       TV     Ranked #94    Members 433,420
# 4                  Pine Jam       TV   Ranked #3997    Members 431,416
# ..                      ...      ...            ...                ...
# 211                          Special   Ranked #5286      Members 3,506
# 212                     PRA  Special   Ranked #8807      Members 2,502
# 213                   Zexcs  Special  Ranked #11324        Members 814
# 214                 FILMONY  Special   Ranked #7378        Members 509
# 215                          Special  Ranked #14133        Members 255
#
#                                            description  \
# 0    After a slow but eventful summer vacation, Shu...
# 1    There is a tower that summons chosen people ca...
# 2    Thanks to Souma Yukihira, Erina Nakiri, and th...
# 3    A year has passed since Tooru Honda began livi...
# 4    Shuuichi Kagaya is what one would consider an ...
# ..                                                 ...
# 211  Compilation of Choujigen Game Neptune The Anim...
# 212  Recap of the first ten episodes of number24 se...
# 213                     Recap episodes of Shadowverse.
# 214  No synopsis information has been added to this...
# 215  Summary of the first 12 episodes of Kotodama S...
#
#                                                img_url  \
# 0    https://cdn.myanimelist.net/images/anime/1764/...
# 1    https://cdn.myanimelist.net/images/anime/1702/...
# 2    https://cdn.myanimelist.net/images/anime/1756/...
# 3    https://cdn.myanimelist.net/images/anime/1972/...
# 4    https://cdn.myanimelist.net/images/anime/1808/...
# ..                                                 ...
# 211  https://cdn.myanimelist.net/images/anime/1395/...
# 212  https://cdn.myanimelist.net/images/anime/1220/...
# 213  https://cdn.myanimelist.net/images/anime/1711/...
# 214  https://cdn.myanimelist.net/images/anime/1156/...
# 215  https://cdn.myanimelist.net/images/anime/1868/...
#
#                                                   link
# 0    https://myanimelist.net/anime/40591/Kaguya-sam...
# 1      https://myanimelist.net/anime/40221/Kami_no_Tou
# 2    https://myanimelist.net/anime/40902/Shokugeki_...
# 3    https://myanimelist.net/anime/40417/Fruits_Bas...
# 4         https://myanimelist.net/anime/39463/Gleipnir
# ..                                                 ...
# 211  https://myanimelist.net/anime/40073/Choujigen_...
# 212  https://myanimelist.net/anime/41586/number24_R...
# 213  https://myanimelist.net/anime/42486/Shadowvers...
# 214  https://myanimelist.net/anime/43020/Yi_Guan_Xi...
# 215  https://myanimelist.net/anime/42699/Microphone...
#
# [216 rows x 11 columns]

# %%
df.to_csv('D:\\Coding\\projects\\anime recommendation\\extract2\\data\\sp20.csv',index=False)
