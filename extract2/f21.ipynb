# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd 
import re

# %%
details=[]
url="https://myanimelist.net/anime/season/2021/fall"
r_actn = requests.get(url)
htmlContent_actn=r_actn.content
soup_actn=BeautifulSoup(htmlContent_actn,'html.parser')
anime_s22=soup_actn.find_all('a',attrs={'class':"link-title",'href': re.compile("^https://")})
    
for text in anime_s22:         
        name=text.get_text()
        url=text.get('href')
        details.append({'title':name,'link':url})

# %%
details

# %%
anime=[]

for i in range(len(details)):
    anime_url=details[i]['link']
    r1=requests.get(anime_url)
    htmlContent1=r1.content
    soup1=BeautifulSoup(htmlContent1,'html.parser')
    jap_name=soup1.find('h1',class_="title-name h1_bold_none").text
    
    
    eng_name=soup1.find('p',class_="title-english title-inherit")
    if eng_name is not None:
        other_name=eng_name.text
    else:
        other_name=""
        
    
    genre=soup1.find_all("span", { 'itemprop':"genre"  })
    g_list=[]        
    for text in genre:
                
        gg=text.get_text()
        g_list.append(gg)
    
    rate=soup1.find('div',class_="score-label")
    if rate is not None:
        ratings=rate.text
    else:
        ratings=""
    
        
    studio=soup1.find('span',class_="information studio author")
    if studio is not None:
        studio_name=soup1.find('span',class_="information studio author").text
    else:
        studio_name=""
      
    type_info=soup1.find('span',class_="information type")
    if type_info is not None:
        type=type_info.text
    else:
        type=""
          
    rank=soup1.find('span',class_="numbers ranked").text
    
    mem=soup1.find('span',class_="numbers members").text
    
    syn=soup1.find("p", { 'itemprop':"description"}).text
    img=soup1.find("img", { 'itemprop':"image"})
    if img is not None:
        img_url=img['data-src']
    else:
        img_url=""

   
    anime.append({'title':jap_name,'title2':other_name,'genre':g_list,'ratings':ratings,'studio':studio_name,'type':type,'rank':rank,'members':mem,'description':syn,'img_url':img_url,'link':anime_url})

# %%
df=pd.DataFrame(anime)
df
# Out:
#                                                  title  \
# 0                         Komi-san wa, Comyushou desu.
# 1      Mushoku Tensei: Isekai Ittara Honki Dasu Part 2
# 2                   Kimetsu no Yaiba: Mugen Ressha-hen
# 3                                       Ousama Ranking
# 4                                     Takt Op. Destiny
# ..                                                 ...
# 244  Vanitas no Karte: Le Chemin Parcouru Depuis la...
# 245                          Lupin III: Part 6 - Jidai
# 246        Girls & Panzer: Saishuushou Part 3 Specials
# 247                        Umayon Shinsaku Short Anime
# 248               Keroro Gunsou x No More Eiga Dorobou
#
#                                              title2  \
# 0                            Komi Can't Communicate
# 1      Mushoku Tensei: Jobless Reincarnation Part 2
# 2    Demon Slayer: Kimetsu no Yaiba Mugen Train Arc
# 3                                  Ranking of Kings
# 4
# ..                                              ...
# 244
# 245
# 246
# 247
# 248  "Stop! Piracy" Sgt. Frog x No More Movie Thief
#
#                                                  genre ratings  \
# 0          [Comedy, Romantic Subtext, School, Shounen]    7.97
# 1       [Drama, Fantasy, Ecchi, Isekai, Reincarnation]    8.72
# 2               [Action, Fantasy, Historical, Shounen]    8.38
# 3                                 [Adventure, Fantasy]    8.58
# 4                             [Action, Fantasy, Music]    7.15
# ..                                                 ...     ...
# 244                [Supernatural, Historical, Vampire]    6.84
# 245  [Action, Adventure, Comedy, Mystery, Adult Cas...    7.32
# 246                         [Comedy, Military, School]    7.23
# 247                          [Comedy, Anthropomorphic]    6.38
# 248                                           [Comedy]     N/A
#
#                                          studio     type           rank  \
# 0                                           OLM       TV    Ranked #611
# 1                                   Studio Bind       TV     Ranked #44
# 2                                      ufotable       TV    Ranked #184
# 3                                    Wit Studio       TV     Ranked #87
# 4                   Madhouse,             MAPPA       TV   Ranked #3286
# ..                                          ...      ...            ...
# 244                                       Bones  Special   Ranked #4688
# 245                           TMS Entertainment  Special   Ranked #2390
# 246                                       Actas  Special   Ranked #2854
# 247  W-Toon Studio,             DMM.futureworks  Special   Ranked #7214
# 248                                              Special  Ranked #21302
#
#              members                                        description  \
# 0    Members 725,932  Hitohito Tadano is an ordinary boy who heads i...
# 1    Members 679,364  After the mysterious mana calamity, Rudeus Gre...
# 2    Members 517,013  A mysterious string of disappearances on a cer...
# 3    Members 491,541  The people of the kingdom look down on the you...
# 4    Members 433,341  The United States of America has been in chaos...
# ..               ...                                                ...
# 244    Members 5,816  Recap of first cours of Vanitas no Karte narra...
# 245    Members 5,151             Episode 0 of Lupin III: Part 6 series.
# 246    Members 4,520  Specials included with Girls & Panzer: Saishuu...
# 247      Members 301  No synopsis information has been added to this...
# 248      Members 203  As the fourth in a series of activities to pro...
#
#                                                img_url  \
# 0    https://cdn.myanimelist.net/images/anime/1899/...
# 1    https://cdn.myanimelist.net/images/anime/1028/...
# 2    https://cdn.myanimelist.net/images/anime/1065/...
# 3    https://cdn.myanimelist.net/images/anime/1347/...
# 4    https://cdn.myanimelist.net/images/anime/1449/...
# ..                                                 ...
# 244  https://cdn.myanimelist.net/images/anime/1401/...
# 245  https://cdn.myanimelist.net/images/anime/1589/...
# 246  https://cdn.myanimelist.net/images/anime/1050/...
# 247  https://cdn.myanimelist.net/images/anime/1294/...
# 248  https://cdn.myanimelist.net/images/anime/1210/...
#
#                                                   link
# 0    https://myanimelist.net/anime/48926/Komi-san_w...
# 1    https://myanimelist.net/anime/45576/Mushoku_Te...
# 2    https://myanimelist.net/anime/49926/Kimetsu_no...
# 3    https://myanimelist.net/anime/40834/Ousama_Ran...
# 4    https://myanimelist.net/anime/48556/Takt_Op_De...
# ..                                                 ...
# 244  https://myanimelist.net/anime/50770/Vanitas_no...
# 245  https://myanimelist.net/anime/50094/Lupin_III_...
# 246  https://myanimelist.net/anime/49690/Girls___Pa...
# 247  https://myanimelist.net/anime/52751/Umayon_Shi...
# 248  https://myanimelist.net/anime/50662/Keroro_Gun...
#
# [249 rows x 11 columns]

# %%
df.to_csv('D:\\Coding\\projects\\anime recommendation\\extract2\\data\\f21.csv',index=False)
