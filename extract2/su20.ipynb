# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd 
import re

# %%
details=[]
url="https://myanimelist.net/anime/season/2020/summer"
r_actn = requests.get(url)
htmlContent_actn=r_actn.content
soup_actn=BeautifulSoup(htmlContent_actn,'html.parser')
anime_s22=soup_actn.find_all('a',attrs={'class':"link-title",'href': re.compile("^https://")})
    
for text in anime_s22:         
        name=text.get_text()
        url=text.get('href')
        details.append({'title':name,'link':url})

# %%
anime=[]

for i in range(len(details)):
    anime_url=details[i]['link']
    r1=requests.get(anime_url)
    htmlContent1=r1.content
    soup1=BeautifulSoup(htmlContent1,'html.parser')
    jap_name=soup1.find('h1',class_="title-name h1_bold_none").text
    
    
    eng_name=soup1.find('p',class_="title-english title-inherit")
    if eng_name is not None:
        other_name=eng_name.text
    else:
        other_name=""
        
    
    genre=soup1.find_all("span", { 'itemprop':"genre"  })
    g_list=[]        
    for text in genre:
                
        gg=text.get_text()
        g_list.append(gg)
    
    rate=soup1.find('div',class_="score-label")
    if rate is not None:
        ratings=rate.text
    else:
        ratings=""
    
        
    studio=soup1.find('span',class_="information studio author")
    if studio is not None:
        studio_name=soup1.find('span',class_="information studio author").text
    else:
        studio_name=""
      
    type_info=soup1.find('span',class_="information type")
    if type_info is not None:
        type=type_info.text
    else:
        type=""
        
    
    rank=soup1.find('span',class_="numbers ranked").text
    
    mem=soup1.find('span',class_="numbers members").text
    
    syn=soup1.find("p", { 'itemprop':"description"}).text
    img=soup1.find("img", { 'itemprop':"image"})
    if img is not None:
        img_url=img['data-src']
    else:
        img_url=""

   
    anime.append({'title':jap_name,'title2':other_name,'genre':g_list,'ratings':ratings,'studio':studio_name,'type':type,'rank':rank,'members':mem,'description':syn,'img_url':img_url,'link':anime_url})

# %%
df=pd.DataFrame(anime)
df
# Out:
#                                                  title  \
# 0     Re:Zero kara Hajimeru Isekai Seikatsu 2nd Season
# 1                                 Kanojo, Okarishimasu
# 2                               The God of High School
# 3    Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 4                       Enen no Shouboutai: Ni no Shou
# ..                                                 ...
# 236                Dokyuu Hentai HxEros: HxEros Report
# 237                       ARP Backstage Pass: Paradise
# 238  Chuukou Ikkan!! Kimetsu Gakuen Monogatari: Kim...
# 239                      Rebirth: Virtual to no Souguu
# 240               Miloha CM:  Oresama ni, Amae Chai na
#
#                                                 title2  \
# 0    Re:ZERO -Starting Life in Another World- Season 2
# 1                                    Rent-a-Girlfriend
# 2
# 3                     The Misfit of Demon King Academy
# 4                                  Fire Force Season 2
# ..                                                 ...
# 236
# 237
# 238                   Kimetsu Academy: Special Edition
# 239
# 240
#
#                                                  genre ratings  \
# 0    [Drama, Fantasy, Suspense, Isekai, Psychologic...    8.36
# 1                           [Comedy, Romance, Shounen]    7.14
# 2         [Action, Fantasy, Martial Arts, Super Power]    7.07
# 3    [Action, Fantasy, Mythology, Reincarnation, Sc...    7.38
# 4                      [Action, Supernatural, Shounen]    7.80
# ..                                                 ...     ...
# 236  [Action, Comedy, Supernatural, Ecchi, School, ...    5.87
# 237                              [Idols (Male), Music]    5.83
# 238                                   [Comedy, School]    6.52
# 239             [Comedy, Slice of Life, Strategy Game]    5.68
# 240                                                 []     N/A
#
#                 studio     type           rank          members  \
# 0            White Fox       TV    Ranked #194  Members 981,680
# 1    TMS Entertainment       TV   Ranked #3330  Members 861,099
# 2                MAPPA       TV   Ranked #3656  Members 805,634
# 3         SILVER LINK.       TV   Ranked #2136  Members 658,502
# 4     David Production       TV    Ranked #911  Members 656,374
# ..                 ...      ...            ...              ...
# 236       Project No.9  Special   Ranked #9906    Members 6,467
# 237    Dynamo Pictures  Special  Ranked #10034    Members 1,122
# 238           ufotable  Special   Ranked #6391    Members 1,059
# 239                     Special  Ranked #10701      Members 762
# 240                     Special  Ranked #14154      Members 157
#
#                                            description  \
# 0    A reunion that was supposed to spell the arriv...
# 1    Kazuya Kinoshita is a 20-year-old college stud...
# 2    The "God of High School" tournament has begun,...
# 3    In the distant past, a war between humans and ...
# 4    After his confrontation in the Nether with his...
# ..                                                 ...
# 236  Recap of the first seven episodes of Dokyuu He...
# 237  Unaired episode included with volume 4 of the ...
# 238  These specials were originally shown at the Ki...
# 239                        Special episode of Rebirth.
# 240  A commercial for Morinaga's "Miloha" supplemen...
#
#                                                img_url  \
# 0    https://cdn.myanimelist.net/images/anime/1444/...
# 1    https://cdn.myanimelist.net/images/anime/1902/...
# 2    https://cdn.myanimelist.net/images/anime/1722/...
# 3    https://cdn.myanimelist.net/images/anime/1126/...
# 4    https://cdn.myanimelist.net/images/anime/1673/...
# ..                                                 ...
# 236  https://cdn.myanimelist.net/images/anime/1284/...
# 237  https://cdn.myanimelist.net/images/anime/1108/...
# 238  https://cdn.myanimelist.net/images/anime/1666/...
# 239  https://cdn.myanimelist.net/images/anime/1757/...
# 240  https://cdn.myanimelist.net/images/anime/1255/...
#
#                                                   link
# 0    https://myanimelist.net/anime/39587/Re_Zero_ka...
# 1    https://myanimelist.net/anime/40839/Kanojo_Oka...
# 2    https://myanimelist.net/anime/41353/The_God_of...
# 3    https://myanimelist.net/anime/40496/Maou_Gakui...
# 4    https://myanimelist.net/anime/40956/Enen_no_Sh...
# ..                                                 ...
# 236  https://myanimelist.net/anime/42685/Dokyuu_Hen...
# 237  https://myanimelist.net/anime/41568/ARP_Backst...
# 238  https://myanimelist.net/anime/48861/Chuukou_Ik...
# 239  https://myanimelist.net/anime/42797/Rebirth__V...
# 240  https://myanimelist.net/anime/42602/Miloha_CM_...
#
# [241 rows x 11 columns]

# %%
df.to_csv('D:\\Coding\\projects\\anime recommendation\\extract2\\data\\su20.csv',index=False)
