# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd 
import re

# %%
details=[]
url="https://myanimelist.net/anime/season/2022/summer"
r_actn = requests.get(url)
htmlContent_actn=r_actn.content
soup_actn=BeautifulSoup(htmlContent_actn,'html.parser')
anime_s22=soup_actn.find_all('a',attrs={'class':"link-title",'href': re.compile("^https://")})
    
for text in anime_s22:         
        name=text.get_text()
        url=text.get('href')
        details.append({'title':name,'link':url})

# %%
anime=[]

for i in range(len(details)):
    anime_url=details[i]['link']
    r1=requests.get(anime_url)
    htmlContent1=r1.content
    soup1=BeautifulSoup(htmlContent1,'html.parser')
    jap_name=soup1.find('h1',class_="title-name h1_bold_none").text
    
    
    eng_name=soup1.find('p',class_="title-english title-inherit")
    if eng_name is not None:
        other_name=eng_name.text
    else:
        other_name=""
        
    
    genre=soup1.find_all("span", { 'itemprop':"genre"  })
    g_list=[]        
    for text in genre:
                
        gg=text.get_text()
        g_list.append(gg)
    
    rate=soup1.find('div',class_="score-label")
    if rate is not None:
        ratings=rate.text
    else:
        ratings=""
    
        
    studio=soup1.find('span',class_="information studio author")
    if studio is not None:
        studio_name=soup1.find('span',class_="information studio author").text
    else:
        studio_name=""
      
    type_info=soup1.find('span',class_="information type")
    if type_info is not None:
        type=type_info.text
    else:
        type=""
        
    
    rank=soup1.find('span',class_="numbers ranked").text
    
    mem=soup1.find('span',class_="numbers members").text
    
    syn=soup1.find("p", { 'itemprop':"description"}).text
    img=soup1.find("img", { 'itemprop':"image"})
    if img is not None:
        img_url=img['data-src']
    else:
        img_url=""

   
    anime.append({'title':jap_name,'title2':other_name,'genre':g_list,'ratings':ratings,'studio':studio_name,'type':type,'rank':rank,'members':mem,'description':syn,'img_url':img_url,'link':anime_url})

# %%
df=pd.DataFrame(anime)
df
# Out:
#                                                  title  \
# 0                                     Yofukashi no Uta
# 1    Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...
# 2                                          Overlord IV
# 3                                 Hataraku Maou-sama!!
# 4                      Kanojo, Okarishimasu 2nd Season
# ..                                                 ...
# 234                                Saraba Nagaki Order
# 235                            Shadowverse Flame Recap
# 236                                Dongitsune Season 2
# 237              Midori no Makibao: Owaranai Chоusen!!
# 238                    Shin Jidai no Webcomic Magazine
#
#                                   title2  \
# 0                      Call of the Night
# 1              Classroom of the Elite II
# 2
# 3    The Devil is a Part-Timer! Season 2
# 4             Rent-a-Girlfriend Season 2
# ..                                   ...
# 234
# 235    Shadowverse Flame Special Episode
# 236
# 237
# 238
#
#                                                  genre ratings  \
# 0            [Romance, Supernatural, Vampire, Shounen]    8.08
# 1             [Drama, Suspense, Psychological, School]    8.16
# 2     [Action, Adventure, Fantasy, Isekai, Video Game]    8.12
# 3    [Comedy, Fantasy, Isekai, Mythology, Romantic ...    6.68
# 4                           [Comedy, Romance, Shounen]    6.88
# ..                                                 ...     ...
# 234                                           [Comedy]    6.22
# 235                           [Fantasy, Strategy Game]    5.83
# 236                                                 []     N/A
# 237                                   [Comedy, Racing]     N/A
# 238                                                 []     N/A
#
#                 studio     type           rank          members  \
# 0           LIDENFILMS       TV    Ranked #484  Members 402,632
# 1               Lerche       TV    Ranked #384  Members 397,217
# 2             Madhouse       TV    Ranked #425  Members 382,065
# 3           Studio 3Hz       TV   Ranked #5514  Members 381,530
# 4    TMS Entertainment       TV   Ranked #4504  Members 329,596
# ..                 ...      ...            ...              ...
# 234                     Special   Ranked #8115      Members 340
# 235              Zexcs  Special  Ranked #10060      Members 312
# 236                     Special  Ranked #19514      Members 153
# 237                     Special  Ranked #14137      Members 148
# 238                     Special  Ranked #15931       Members 58
#
#                                            description  \
# 0    Kou Yamori is an average middle school student...
# 1    Life back on the cruise following the Island S...
# 2    E-Rantel, the capital city of the newly establ...
# 3    The once-feared Demon Lord Satan of Ente Isla,...
# 4    A year after they met, Kazuya Kinoshita and Ch...
# ..                                                 ...
# 234  In this new 30-second ad, entitled Goodbye to ...
# 235    Recap of episodes 1 to 25 of Shadowverse Flame.
# 236  A continuation of the Dongitsune live action C...
# 237  An adaptation of the final episode of the Mido...
# 238  A short commercial for Kadokawa with Showa-sty...
#
#                                                img_url  \
# 0    https://cdn.myanimelist.net/images/anime/1045/...
# 1    https://cdn.myanimelist.net/images/anime/1010/...
# 2    https://cdn.myanimelist.net/images/anime/1530/...
# 3    https://cdn.myanimelist.net/images/anime/1502/...
# 4    https://cdn.myanimelist.net/images/anime/1070/...
# ..                                                 ...
# 234  https://cdn.myanimelist.net/images/anime/1068/...
# 235  https://cdn.myanimelist.net/images/anime/1607/...
# 236  https://cdn.myanimelist.net/images/anime/1424/...
# 237  https://cdn.myanimelist.net/images/anime/1907/...
# 238  https://cdn.myanimelist.net/images/anime/1396/...
#
#                                                   link
# 0    https://myanimelist.net/anime/50346/Yofukashi_...
# 1    https://myanimelist.net/anime/51096/Youkoso_Ji...
# 2      https://myanimelist.net/anime/48895/Overlord_IV
# 3    https://myanimelist.net/anime/48413/Hataraku_M...
# 4    https://myanimelist.net/anime/42963/Kanojo_Oka...
# ..                                                 ...
# 234  https://myanimelist.net/anime/53183/Saraba_Nag...
# 235  https://myanimelist.net/anime/53135/Shadowvers...
# 236  https://myanimelist.net/anime/53443/Dongitsune...
# 237  https://myanimelist.net/anime/52071/Midori_no_...
# 238  https://myanimelist.net/anime/53479/Shin_Jidai...
#
# [239 rows x 11 columns]

# %%
df.to_csv('D:\\Coding\\projects\\anime recommendation\\extract2\\su22.csv',index=False)
