# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd 
import re

# %%
details=[]
url="https://myanimelist.net/anime/season/2021/spring"
r_actn = requests.get(url)
htmlContent_actn=r_actn.content
soup_actn=BeautifulSoup(htmlContent_actn,'html.parser')
anime_s22=soup_actn.find_all('a',attrs={'class':"link-title",'href': re.compile("^https://")})
    
for text in anime_s22:         
        name=text.get_text()
        url=text.get('href')
        details.append({'title':name,'link':url})

# %%
details

# %%
anime=[]

for i in range(len(details)):
    anime_url=details[i]['link']
    r1=requests.get(anime_url)
    htmlContent1=r1.content
    soup1=BeautifulSoup(htmlContent1,'html.parser')
    jap_name=soup1.find('h1',class_="title-name h1_bold_none").text
    
    
    eng_name=soup1.find('p',class_="title-english title-inherit")
    if eng_name is not None:
        other_name=eng_name.text
    else:
        other_name=""
        
    
    genre=soup1.find_all("span", { 'itemprop':"genre"  })
    g_list=[]        
    for text in genre:
                
        gg=text.get_text()
        g_list.append(gg)
    
    rate=soup1.find('div',class_="score-label")
    if rate is not None:
        ratings=rate.text
    else:
        ratings=""
    
        
    studio=soup1.find('span',class_="information studio author")
    if studio is not None:
        studio_name=soup1.find('span',class_="information studio author").text
    else:
        studio_name=""
      
    type_info=soup1.find('span',class_="information type")
    if type_info is not None:
        type=type_info.text
    else:
        type=""
        
    
    rank=soup1.find('span',class_="numbers ranked").text
    
    mem=soup1.find('span',class_="numbers members").text
    
    syn=soup1.find("p", { 'itemprop':"description"}).text
    img=soup1.find("img", { 'itemprop':"image"})
    if img is not None:
        img_url=img['data-src']
    else:
        img_url=""

   
    anime.append({'title':jap_name,'title2':other_name,'genre':g_list,'ratings':ratings,'studio':studio_name,'type':type,'rank':rank,'members':mem,'description':syn,'img_url':img_url,'link':anime_url})

# %%
df=pd.DataFrame(anime)
df
# Out:
#                                                  title  \
# 0                                      Tokyo Revengers
# 1                     Boku no Hero Academia 5th Season
# 2                                   Fumetsu no Anata e
# 3                             Ijiranaide, Nagatoro-san
# 4                                                   86
# ..                                                 ...
# 237  Dragon Quest: Dai no Daibouken (2020): Bouken ...
# 238          Ani x Para: Anata no Hero wa Dare desu ka
# 239      Ensemble Stars!! 5th Anniversary Animation PV
# 240                                      iichiko Story
# 241              Bonus Track: Atarashii Yoru no Hanami
#
#                                                 title2  \
# 0
# 1                            My Hero Academia Season 5
# 2                                     To Your Eternity
# 3                     Don't Toy with Me, Miss Nagatoro
# 4                                        86 Eighty Six
# ..                                                 ...
# 237  Dragon Quest: The Adventure of Dai: The Trail ...
# 238          Animation × Paralympic: Who Is Your Hero?
# 239
# 240
# 241
#
#                                                  genre ratings  \
# 0    [Action, Drama, Supernatural, Delinquents, Sch...    8.06
# 1               [Action, School, Super Power, Shounen]    7.41
# 2            [Adventure, Drama, Supernatural, Shounen]    8.38
# 3                   [Comedy, Romantic Subtext, School]    7.35
# 4             [Action, Drama, Sci-Fi, Mecha, Military]    8.26
# ..                                                 ...     ...
# 237              [Action, Adventure, Fantasy, Shounen]    6.17
# 238                              [Sports, Educational]    6.48
# 239                              [Idols (Male), Music]    6.70
# 240                        [Slice of Life, Adult Cast]     N/A
# 241                                      [Avant Garde]     N/A
#
#                                                 studio     type  \
# 0                                           LIDENFILMS       TV
# 1                                                Bones       TV
# 2                                         Brain's Base       TV
# 3                               Telecom Animation Film       TV
# 4                                         A-1 Pictures       TV
# ..                                                 ...      ...
# 237                                     Toei Animation  Special
# 238  Nippon Animation,             Gallop,         ...  Special
# 239                                   David Production  Special
# 240                     DR Movie,             Chiptune  Special
# 241                                                     Special
#
#               rank            members  \
# 0      Ranked #513  Members 1,039,020
# 1     Ranked #2033    Members 987,761
# 2      Ranked #183    Members 740,710
# 3     Ranked #2289    Members 686,904
# 4      Ranked #274    Members 602,042
# ..             ...                ...
# 237   Ranked #8365      Members 2,192
# 238   Ranked #6625      Members 1,035
# 239   Ranked #5382        Members 919
# 240  Ranked #20688         Members 70
# 241  Ranked #18823         Members 61
#
#                                            description  \
# 0    Takemichi Hanagaki's second year of middle sch...
# 1    UA Academy's Class 1-A has been the focus of a...
# 2    An Orb, known only as It, is cast to Earth to ...
# 3    Every day, Naoto Hachiouji is teased relentles...
# 4    According to the Republic of San Magnolia, the...
# ..                                                 ...
# 237  Recap of first 37 episodes of Dragon Quest: Da...
# 238  NHK specials on parasports. The first episode ...
# 239  A video uploaded to the Happy Elements YouTube...
# 240  Animated commercials for the iichiko beverage ...
# 241  Five short animations screened at the in-perso...
#
#                                                img_url  \
# 0    https://cdn.myanimelist.net/images/anime/1839/...
# 1    https://cdn.myanimelist.net/images/anime/1911/...
# 2    https://cdn.myanimelist.net/images/anime/1880/...
# 3    https://cdn.myanimelist.net/images/anime/1900/...
# 4    https://cdn.myanimelist.net/images/anime/1987/...
# ..                                                 ...
# 237  https://cdn.myanimelist.net/images/anime/1762/...
# 238  https://cdn.myanimelist.net/images/anime/1336/...
# 239  https://cdn.myanimelist.net/images/anime/1424/...
# 240  https://cdn.myanimelist.net/images/anime/1274/...
# 241  https://cdn.myanimelist.net/images/anime/1730/...
#
#                                                   link
# 0    https://myanimelist.net/anime/42249/Tokyo_Reve...
# 1    https://myanimelist.net/anime/41587/Boku_no_He...
# 2    https://myanimelist.net/anime/41025/Fumetsu_no...
# 3    https://myanimelist.net/anime/42361/Ijiranaide...
# 4               https://myanimelist.net/anime/41457/86
# ..                                                 ...
# 237  https://myanimelist.net/anime/49228/Dragon_Que...
# 238  https://myanimelist.net/anime/37290/Ani_x_Para...
# 239  https://myanimelist.net/anime/49060/Ensemble_S...
# 240  https://myanimelist.net/anime/52227/iichiko_Story
# 241  https://myanimelist.net/anime/53015/Bonus_Trac...
#
# [242 rows x 11 columns]

# %%
df.to_csv('D:\\Coding\\projects\\anime recommendation\\extract2\\data\\sp21.csv',index=False)
