# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd 
import re

# %%
details=[]
url="https://myanimelist.net/anime/season/2021/summer"
r_actn = requests.get(url)
htmlContent_actn=r_actn.content
soup_actn=BeautifulSoup(htmlContent_actn,'html.parser')
anime_s22=soup_actn.find_all('a',attrs={'class':"link-title",'href': re.compile("^https://")})
    
for text in anime_s22:         
        name=text.get_text()
        url=text.get('href')
        details.append({'title':name,'link':url})

# %%
anime=[]

for i in range(len(details)):
    anime_url=details[i]['link']
    r1=requests.get(anime_url)
    htmlContent1=r1.content
    soup1=BeautifulSoup(htmlContent1,'html.parser')
    jap_name=soup1.find('h1',class_="title-name h1_bold_none").text
    
    
    eng_name=soup1.find('p',class_="title-english title-inherit")
    if eng_name is not None:
        other_name=eng_name.text
    else:
        other_name=""
        
    
    genre=soup1.find_all("span", { 'itemprop':"genre"  })
    g_list=[]        
    for text in genre:
                
        gg=text.get_text()
        g_list.append(gg)
    
    rate=soup1.find('div',class_="score-label")
    if rate is not None:
        ratings=rate.text
    else:
        ratings=""
    
        
    studio=soup1.find('span',class_="information studio author")
    if studio is not None:
        studio_name=soup1.find('span',class_="information studio author").text
    else:
        studio_name=""
      
    type_info=soup1.find('span',class_="information type")
    if type_info is not None:
        type=type_info.text
    else:
        type=""
        
    
    rank=soup1.find('span',class_="numbers ranked").text
    
    mem=soup1.find('span',class_="numbers members").text
    
    syn=soup1.find("p", { 'itemprop':"description"}).text
    img=soup1.find("img", { 'itemprop':"image"})
    if img is not None:
        img_url=img['data-src']
    else:
        img_url=""

   
    anime.append({'title':jap_name,'title2':other_name,'genre':g_list,'ratings':ratings,'studio':studio_name,'type':type,'rank':rank,'members':mem,'description':syn,'img_url':img_url,'link':anime_url})

# %%
df=pd.DataFrame(anime)
df
# Out:
#                                                  title  \
# 0     Tensei shitara Slime Datta Ken 2nd Season Part 2
# 1                   Kobayashi-san Chi no Maid Dragon S
# 2                                     Vanitas no Karte
# 3                            Tantei wa Mou, Shindeiru.
# 4                    Tsuki ga Michibiku Isekai Douchuu
# ..                                                 ...
# 249                                 Natsu ga Hajimaru.
# 250                                     Pochama Sweets
# 251  Kick & Slide: Kids B Happy no Ambassador wo Sa...
# 252                  100-nichikan Ikita Wani X Bourbon
# 253              Bonus Track: Atarashii Yoru no Hanabi
#
#                                                 title2  \
# 0    That Time I Got Reincarnated as a Slime Season...
# 1                       Miss Kobayashi's Dragon Maid S
# 2                            The Case Study of Vanitas
# 3                        The Detective Is Already Dead
# 4                         Tsukimichi -Moonlit Fantasy-
# ..                                                 ...
# 249
# 250
# 251
# 252       A Crocodile Who Lived For 100 Days X Bourbon
# 253
#
#                                                  genre ratings  \
# 0    [Action, Adventure, Comedy, Fantasy, Isekai, M...    8.32
# 1                             [Fantasy, Slice of Life]    8.34
# 2         [Supernatural, Historical, Vampire, Shounen]    7.91
# 3                    [Comedy, Drama, Mystery, Romance]    6.35
# 4         [Action, Adventure, Comedy, Fantasy, Isekai]    7.72
# ..                                                 ...     ...
# 249                                           [Sports]    6.47
# 250                                     [Comedy, Kids]    5.64
# 251                                      [Music, Kids]     N/A
# 252                   [Slice of Life, Anthropomorphic]     N/A
# 253                                      [Avant Garde]     N/A
#
#               studio     type           rank          members  \
# 0               8bit       TV    Ranked #227  Members 602,024
# 1    Kyoto Animation       TV    Ranked #207  Members 479,848
# 2              Bones       TV    Ranked #712  Members 429,543
# 3               ENGI       TV   Ranked #7373  Members 320,433
# 4                C2C       TV   Ranked #1083  Members 315,819
# ..               ...      ...            ...              ...
# 249                   Special   Ranked #6691      Members 325
# 250                   Special  Ranked #10860      Members 251
# 251                   Special  Ranked #21319      Members 126
# 252                   Special  Ranked #18211       Members 97
# 253                   Special  Ranked #18822       Members 62
#
#                                            description  \
# 0    The nation of Tempest is in a festive mood aft...
# 1    As Tooru continues on her quest to become the ...
# 2    Scorned by others of his kind for being born u...
# 3    Kimihiko Kimizuka has found himself inadverten...
# 4    As part of a mysterious contract agreed upon b...
# ..                                                 ...
# 249  A CalorieMate promotional animation with contr...
# 250  Special animation from Project Pochama for Pok...
# 251                   A bonus episode of Kick & Slide.
# 252  No synopsis information has been added to this...
# 253  Four short animations screened at the in-perso...
#
#                                                img_url  \
# 0    https://cdn.myanimelist.net/images/anime/1033/...
# 1    https://cdn.myanimelist.net/images/anime/1252/...
# 2    https://cdn.myanimelist.net/images/anime/1401/...
# 3    https://cdn.myanimelist.net/images/anime/1843/...
# 4    https://cdn.myanimelist.net/images/anime/1950/...
# ..                                                 ...
# 249  https://cdn.myanimelist.net/images/anime/1301/...
# 250  https://cdn.myanimelist.net/images/anime/1640/...
# 251  https://cdn.myanimelist.net/images/anime/1089/...
# 252  https://cdn.myanimelist.net/images/anime/1985/...
# 253  https://cdn.myanimelist.net/images/anime/1252/...
#
#                                                   link
# 0    https://myanimelist.net/anime/41487/Tensei_shi...
# 1    https://myanimelist.net/anime/39247/Kobayashi-...
# 2    https://myanimelist.net/anime/48580/Vanitas_no...
# 3    https://myanimelist.net/anime/46471/Tantei_wa_...
# 4    https://myanimelist.net/anime/43523/Tsuki_ga_M...
# ..                                                 ...
# 249  https://myanimelist.net/anime/49581/Natsu_ga_H...
# 250  https://myanimelist.net/anime/51018/Pochama_Sw...
# 251  https://myanimelist.net/anime/49963/Kick___Sli...
# 252  https://myanimelist.net/anime/49414/100-nichik...
# 253  https://myanimelist.net/anime/49584/Bonus_Trac...
#
# [254 rows x 11 columns]

# %%
df.to_csv('D:\\Coding\\projects\\anime recommendation\\extract2\\data\\su21.csv',index=False)
