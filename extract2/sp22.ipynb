# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd 
import re

# %%
details=[]
url="https://myanimelist.net/anime/season/2022/spring"
r_actn = requests.get(url)
htmlContent_actn=r_actn.content
soup_actn=BeautifulSoup(htmlContent_actn,'html.parser')
anime_s22=soup_actn.find_all('a',attrs={'class':"link-title",'href': re.compile("^https://")})
    
for text in anime_s22:         
        name=text.get_text()
        url=text.get('href')
        details.append({'title':name,'link':url})

# %%
details

# %%
anime=[]

for i in range(len(details)):
    anime_url=details[i]['link']
    r1=requests.get(anime_url)
    htmlContent1=r1.content
    soup1=BeautifulSoup(htmlContent1,'html.parser')
    jap_name=soup1.find('h1',class_="title-name h1_bold_none").text
    
    
    eng_name=soup1.find('p',class_="title-english title-inherit")
    if eng_name is not None:
        other_name=eng_name.text
    else:
        other_name=""
        
    
    genre=soup1.find_all("span", { 'itemprop':"genre"  })
    g_list=[]        
    for text in genre:
                
        gg=text.get_text()
        g_list.append(gg)
    
    rate=soup1.find('div',class_="score-label")
    if rate is not None:
        ratings=rate.text
    else:
        ratings=""
    
        
    studio=soup1.find('span',class_="information studio author")
    if studio is not None:
        studio_name=soup1.find('span',class_="information studio author").text
    else:
        studio_name=""
      
    type_info=soup1.find('span',class_="information type")
    if type_info is not None:
        type=type_info.text
    else:
        type=""
        
    
    rank=soup1.find('span',class_="numbers ranked").text
    
    mem=soup1.find('span',class_="numbers members").text
    
    syn=soup1.find("p", { 'itemprop':"description"}).text
    img=soup1.find("img", { 'itemprop':"image"})
    if img is not None:
        img_url=img['data-src']
    else:
        img_url=""

   
    anime.append({'title':jap_name,'title2':other_name,'genre':g_list,'ratings':ratings,'studio':studio_name,'type':type,'rank':rank,'members':mem,'description':syn,'img_url':img_url,'link':anime_url})

# %%
df=pd.DataFrame(anime)
df
# Out:
#                                                  title  \
# 0                                         Spy x Family
# 1           Kaguya-sama wa Kokurasetai: Ultra Romantic
# 2                 Tate no Yuusha no Nariagari Season 2
# 3                     Kawaii dake ja Nai Shikimori-san
# 4              Komi-san wa, Comyushou desu. 2nd Season
# ..                                                 ...
# 213  Detective Conan: Love Story at Police Headquar...
# 214           Shin Gakki da yo! Waccha PriMagi! Gakuen
# 215                                    Usagi (Special)
# 216                     DEathMAtCH: Real ni Koishiteru
# 217                                   Over the Rainbow
#
#                                         title2  \
# 0
# 1    Kaguya-sama: Love is War - Ultra Romantic
# 2       The Rising of the Shield Hero Season 2
# 3                 Shikimori's Not Just a Cutie
# 4              Komi Can't Communicate Season 2
# ..                                         ...
# 213
# 214
# 215                                      Usagi
# 216
# 217
#
#                                                  genre ratings  \
# 0                 [Action, Comedy, Childcare, Shounen]    8.72
# 1     [Comedy, Romance, Psychological, School, Seinen]    9.09
# 2          [Action, Adventure, Drama, Fantasy, Isekai]    6.56
# 3                            [Comedy, Romance, School]    6.94
# 4          [Comedy, Romantic Subtext, School, Shounen]    8.12
# ..                                                 ...     ...
# 213  [Adventure, Comedy, Mystery, Romance, Detectiv...    6.61
# 214                    [Comedy, Idols (Female), Music]     N/A
# 215                                  [Comedy, Fantasy]     N/A
# 216                           [Action, Comedy, Sci-Fi]     N/A
# 217                                  [Comedy, Fantasy]     N/A
#
#                                   studio     type           rank  \
# 0    Wit Studio,             CloverWorks       TV     Ranked #45
# 1                           A-1 Pictures       TV      Ranked #3
# 2    Kinema Citrus,             DR Movie       TV   Ranked #6154
# 3                              Doga Kobo       TV   Ranked #4231
# 4                                    OLM       TV    Ranked #421
# ..                                   ...      ...            ...
# 213                    TMS Entertainment  Special   Ranked #5872
# 214                                       Special  Ranked #15929
# 215                               Orange  Special  Ranked #16981
# 216                               Orange  Special  Ranked #19407
# 217                               Orange  Special  Ranked #14912
#
#                members                                        description  \
# 0    Members 1,115,937  Corrupt politicians, frenzied nationalists, an...
# 1      Members 696,036  The elite members of Shuchiin Academy's studen...
# 2      Members 627,141  With another Wave happening in a week, Naofumi...
# 3      Members 406,837  Yuu Izumi leads a high school life filled with...
# 4      Members 365,920  After an exciting and momentous cultural festi...
# ..                 ...                                                ...
# 213        Members 578  The special contains the footage from episodes...
# 214        Members 321  No synopsis information has been added to this...
# 215        Members 127  Original anime short that aired during the Fuj...
# 216        Members 126  Original anime short that aired during the Fuj...
# 217        Members 118  Original anime short that aired during the Fuj...
#
#                                                img_url  \
# 0    https://cdn.myanimelist.net/images/anime/1441/...
# 1    https://cdn.myanimelist.net/images/anime/1160/...
# 2    https://cdn.myanimelist.net/images/anime/1143/...
# 3    https://cdn.myanimelist.net/images/anime/1995/...
# 4    https://cdn.myanimelist.net/images/anime/1108/...
# ..                                                 ...
# 213  https://cdn.myanimelist.net/images/anime/1774/...
# 214  https://cdn.myanimelist.net/images/anime/1955/...
# 215  https://cdn.myanimelist.net/images/anime/1072/...
# 216  https://cdn.myanimelist.net/images/anime/1761/...
# 217  https://cdn.myanimelist.net/images/anime/1851/...
#
#                                                   link
# 0     https://myanimelist.net/anime/50265/Spy_x_Family
# 1    https://myanimelist.net/anime/43608/Kaguya-sam...
# 2    https://myanimelist.net/anime/40356/Tate_no_Yu...
# 3    https://myanimelist.net/anime/45613/Kawaii_dak...
# 4    https://myanimelist.net/anime/50631/Komi-san_w...
# ..                                                 ...
# 213  https://myanimelist.net/anime/51782/Detective_...
# 214  https://myanimelist.net/anime/51538/Shin_Gakki...
# 215  https://myanimelist.net/anime/52226/Usagi_Special
# 216  https://myanimelist.net/anime/52228/DEathMAtCH...
# 217  https://myanimelist.net/anime/52225/Over_the_R...
#
# [218 rows x 11 columns]

# %%
df.to_csv('D:\\Coding\\projects\\anime recommendation\\extract2\\data\\sp22.csv',index=False)
